# %% [markdown]
# **ИССЛЕДОВАТЕЛЬСКИЙ АНАЛИЗ ДАННЫХ**

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # **<font color='DarkRed'> Исследование объявлений о продаже квартир </font>**
#
# В нашем распоряжении данные сервиса **<font color='FireBrick'> Яндекс.Недвижимость </font>**  — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# **<font color='red'> Цель исследования</font>** - научиться определять рыночную стоимость объектов недвижимости.
#
# Наша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## **<font color='FireBrick'> Описание данных </font>**  ###

# %% [markdown]
# **<font color='OrangeRed'> airports_nearest </font>**  — расстояние до ближайшего аэропорта в метрах (м)
# **<font color='OrangeRed'> balcony </font>**  — число балконов
# **<font color='OrangeRed'> ceiling_height </font>**   — высота потолков (м)
# **<font color='OrangeRed'> cityCenters_nearest </font>**   — расстояние до центра города (м)
# **<font color='OrangeRed'> days_exposition </font>**   — сколько дней было размещено объявление (от публикации до снятия)
# **<font color='OrangeRed'> first_day_exposition </font>**   — дата публикации
# **<font color='OrangeRed'> floor </font>**  — этаж
# **<font color='OrangeRed'> floors_total </font>**   — всего этажей в доме
# **<font color='OrangeRed'> is_apartment </font>**   — апартаменты (булев тип)
# **<font color='OrangeRed'> kitchen_area </font>**   — площадь кухни в квадратных метрах (м²)
# **<font color='OrangeRed'> last_price </font>**   — цена на момент снятия с публикации
# **<font color='OrangeRed'> living_area </font>**   — жилая площадь в квадратных метрах (м²)
# **<font color='OrangeRed'> locality_name </font>**   — название населённого пункта
# **<font color='OrangeRed'> open_plan </font>**   — свободная планировка (булев тип)
# **<font color='OrangeRed'> parks_around3000 </font>**  — число парков в радиусе 3 км
# **<font color='OrangeRed'> parks_nearest </font>**  — расстояние до ближайшего парка (м)
# **<font color='OrangeRed'> ponds_around3000 </font>**  — число водоёмов в радиусе 3 км
# **<font color='OrangeRed'> ponds_nearest </font>**  — расстояние до ближайшего водоёма (м)
# **<font color='OrangeRed'> rooms </font>**  — число комнат
# **<font color='OrangeRed'> studio </font>**  — квартира-студия (булев тип)
# **<font color='OrangeRed'> total_area </font>**  — площадь квартиры в квадратных метрах (м²)
# **<font color='OrangeRed'> total_images </font>**  — число фотографий квартиры в объявлении

# %% [markdown]
# ## **<font color='Crimson'> Изучение данных из файла </font>**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.lines import Line2D
import numpy as np
from datetime import datetime  # получить день недели из даты
pd.options.mode.chained_assignment = None  # отключить предупреждения Pandas
from IPython.display import Image
from IPython.display import HTML
import base64
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
#добавим красоты в оформление проекта

from IPython.core.display import display, HTML

display(HTML("<font color='blue'>синий текст</font>"))
display(HTML("<font color='maroon'>коричневый текст</font>"))
display(HTML("<font color='olive'>текст оливкогового цвета</font>"))
display(HTML("<font color='navy'>темно-синий текст</font>"))
display(HTML("<font color='purple'> фиолетовый текст</font>"))
display(HTML("<font color='teal'>бирюзовый текст</font>"))
display(HTML("<font color='gray'>серый текст</font>"))
display(HTML("<font color='lime'>светло-зеленый текст</font>"))
display(HTML("<font color='green'>зеленый текст</font>"))
display(HTML("<font color='yellow'>желтый текст</font>"))
display(HTML("<font color='FUCHSIA'> розовый текст</font>"))
display(HTML("<font color='AQUA'> голубой текст</font>"))
# Out:
# <font color='blue'>синий текст</font>
# <font color='maroon'>коричневый текст</font>
# <font color='olive'>текст оливкогового цвета</font>
# <font color='navy'>темно-синий текст</font>
# <font color='purple'> фиолетовый текст</font>
# <font color='teal'>бирюзовый текст</font>
# <font color='gray'>серый текст</font>
# <font color='lime'>светло-зеленый текст</font>
# <font color='green'>зеленый текст</font>
# <font color='yellow'>желтый текст</font>
# <font color='FUCHSIA'> розовый текст</font>
# <font color='AQUA'> голубой текст</font>

# %%
flats = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
flats.head()
# Out:
#    total_images    last_price  total_area first_day_exposition  rooms  \
# 0            20 13,000,000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3,350,000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5,196,000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64,900,000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10,000,000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70         16.00        51.00      8          NaN  ...
# 1             nan         11.00        18.60      1          NaN  ...
# 2             nan          5.00        34.30      4          NaN  ...
# 3             nan         14.00          nan      9          NaN  ...
# 4            3.03         14.00        32.00     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
flats.tail()
# Out:
#        total_images    last_price  total_area first_day_exposition  rooms  \
# 23694             9  9,700,000.00      133.81  2017-03-21T00:00:00      3
# 23695            14  3,100,000.00       59.00  2018-01-15T00:00:00      3
# 23696            18  2,500,000.00       56.70  2018-02-11T00:00:00      2
# 23697            13 11,475,000.00       76.75  2017-03-28T00:00:00      2
# 23698             4  1,350,000.00       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23694            3.70          5.00        73.30      3          NaN  ...
# 23695             nan          5.00        38.00      4          NaN  ...
# 23696             nan          3.00        29.70      1          NaN  ...
# 23697            3.00         17.00          nan     12          NaN  ...
# 23698            2.50          5.00        12.30      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# ...

# %%
flats.sample()
# Out:
#       total_images   last_price  total_area first_day_exposition  rooms  \
# 8471             7 9,900,000.00       80.30  2017-06-29T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 8471            3.00          8.00        42.60      4        False  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# 8471         15.80      nan  Санкт-Петербург         39,393.00
#
#      cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 8471           11,096.00              1.00         537.00              0.00
#
#       ponds_nearest  days_exposition
# 8471            nan           196.00
#
# [1 rows x 22 columns]

# %%
#общая информация о датафрейме

flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23637 entries, 0 to 23698
# Data columns (total 30 columns):
# total_images            23637 non-null int64
# last_price              23637 non-null int64
# total_area              23637 non-null float64
# first_day_exposition    23637 non-null datetime64[ns]
# rooms                   23637 non-null int64
# ceiling_height          23637 non-null float64
# floors_total            23637 non-null int64
# living_area             21744 non-null float64
# floor                   23637 non-null int64
# is_apartment            23637 non-null bool
# studio                  23637 non-null bool
# open_plan               23637 non-null bool
# kitchen_area            23637 non-null float64
# balcony                 23637 non-null int64
# locality_name           23613 non-null object
# airports_nearest        18111 non-null float64
# cityCenters_nearest     18134 non-null float64
# parks_around3000        18135 non-null float64
# ...

# %%
# подсчет пропусков

display('Пропуски в столбце "высота потолков (м)"'':', flats['ceiling_height'].isna().sum())
display('Пропуски в столбце "общая этажность дома"'':', flats['floors_total'].isna().sum())
display('Пропуски в столбце "жилая площадь"'':', flats['living_area'].isna().sum())
display('Пропуски в столбце "апартаменты (булев тип)"'':', flats['is_apartment'].isna().sum())
display('Пропуски в столбце "число балконов"'':', flats['balcony'].isna().sum())
display('Пропуски в столбце "название населённого пункта"'':', flats['locality_name'].isna().sum())
display('Пропуски в столбце "расстояние до ближайшего аэропорта в метрах (м)"'':', flats['airports_nearest'].isna().sum())
display('Пропуски в столбце "расстояние до центра города (м)"'':', flats['cityCenters_nearest'].isna().sum())
display('Пропуски в столбце "число парков в радиусе 3 км"'':', flats['parks_around3000'].isna().sum())
display('Пропуски в столбце "расстояние до ближайшего парка (м)"'':', flats['parks_nearest'].isna().sum())
display('Пропуски в столбце "число водоёмов в радиусе 3 км"'':', flats['ponds_around3000'].isna().sum())
display('Пропуски в столбце "расстояние до ближайшего водоёма (м)"'':', flats['ponds_nearest'].isna().sum())
display('Пропуски в столбце "сколько дней было размещено объявление (от публикации до снятия)"'':', flats['days_exposition'].isna().sum())
# Out:
# 'Пропуски в столбце "высота потолков (м)":'
# 9195
# 'Пропуски в столбце "общая этажность дома":'
# 86
# 'Пропуски в столбце "жилая площадь":'
# 1903
# 'Пропуски в столбце "апартаменты (булев тип)":'
# 20924
# 'Пропуски в столбце "число балконов":'
# 11519
# 'Пропуски в столбце "название населённого пункта":'
# 49
# 'Пропуски в столбце "расстояние до ближайшего аэропорта в метрах (м)":'
# 5542
# 'Пропуски в столбце "расстояние до центра города (м)":'
# 5519
# 'Пропуски в столбце "число парков в радиусе 3 км":'
# 5518
# 'Пропуски в столбце "расстояние до ближайшего парка (м)":'
# 15620
# 'Пропуски в столбце "число водоёмов в радиусе 3 км":'
# 5518
# 'Пропуски в столбце "расстояние до ближайшего водоёма (м)":'
# 14589
# 'Пропуски в столбце "сколько дней было размещено объявление (от публикации до снятия)":'
# 3181

# %% [markdown]
# Посчитаем количество пропусков:

# %%
flats.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Посмотрим долю пропусков:

# %%
flats.isna().mean()
# Out:
# total_images           0.00
# last_price             0.00
# total_area             0.00
# first_day_exposition   0.00
# rooms                  0.00
# ceiling_height         0.39
# floors_total           0.00
# living_area            0.08
# floor                  0.00
# is_apartment           0.88
# studio                 0.00
# open_plan              0.00
# kitchen_area           0.10
# balcony                0.49
# locality_name          0.00
# airports_nearest       0.23
# cityCenters_nearest    0.23
# parks_around3000       0.23
# parks_nearest          0.66
# ponds_around3000       0.23
# ponds_nearest          0.62
# days_exposition        0.13
# dtype: float64

# %% [markdown]
# Посмотрим на долю пропусков в процентах с округлением до двух цифр после запятой:

# %%
round(flats.isna().sum() * 100 / len(flats), 2)
# Out:
# total_images            0.00
# last_price              0.00
# total_area              0.00
# first_day_exposition    0.00
# rooms                   0.00
# ceiling_height         38.80
# floors_total            0.36
# living_area             8.03
# floor                   0.00
# is_apartment           88.29
# studio                  0.00
# open_plan               0.00
# kitchen_area            9.61
# balcony                48.61
# locality_name           0.21
# airports_nearest       23.38
# cityCenters_nearest    23.29
# parks_around3000       23.28
# parks_nearest          65.91
# ponds_around3000       23.28
# ponds_nearest          61.56
# days_exposition        13.42
# dtype: float64

# %% [markdown]
# Это пока краткий обзор пропусков и их количества в рамках изучения общей информации о наших данных. К пропускам, их количеству и причинам мы вернемся в разделе "предобработка данных". Я специально поместила большую часть информации по пропускам в "Предобработку данных" для удобства, чтобы проще было их обрабатывать, не возвращаясь после каждой обработки сюда и не перематывая каждый раз Jupyter от одной главы исследования к другой и обратно.

# %%
# с помощью атрибута shape мы можем узнать количество строк (первая цифра) и столбцов (вторая цифра) в датафрейме

flats.shape
# Out:
# (23699, 22)

# %% [markdown]
# В нашем датасете 23699 строк и  22 столбца

# %%
# типы данных

flats.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment             object
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# cityCenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %%
flats.dtypes.value_counts()
# Out:
# float64    14
# object      3
# int64       3
# bool        2
# dtype: int64

# %% [markdown]
# При помощи атрибута **dtypes** мы видим, какие типы данных есть в нашем датафрейме.
#
# **<font color='IndianRed'> В нашем датафрейме встречаются данные трех типов: </font>**
#
# **<font color='OrangeRed'> float64 </font>**  -  дробное число (также известное как "число с плавающей точкой", вещественный тип данных). Самый распространенный тип данных в этом датасете, примерно 2/3  всех данных
# **<font color='OrangeRed'> object </font>**  - текст
# **<font color='OrangeRed'> int64 </font>**  - целое число (оно же - целочисленный тип данных)
# **<font color='OrangeRed'> bool </font>**  - Логи́ческий тип да́нных, или булев тип, или булевый тип (от англ. Boolean или logical data type) —  тип данных, принимающий два возможных значения: истина (true) и ложь (false).

# %%
# описание данных 
# пользуясь методом describe, смотрим на описательную статистику числовых данных:
# минимальные (min) и максимальные (max) значения столбцов, среднее (mean), медиана (median), стандратное отклонение (std)
# и процентили (25%, 50%, 75%). 

flats.describe()
# Out:
#        total_images     last_price  total_area     rooms  ceiling_height  \
# count     23,699.00      23,699.00   23,699.00 23,699.00       14,504.00
# mean           9.86   6,541,548.77       60.35      2.07            2.77
# std            5.68  10,887,013.27       35.65      1.08            1.26
# min            0.00      12,190.00       12.00      0.00            1.00
# 25%            6.00   3,400,000.00       40.00      1.00            2.52
# 50%            9.00   4,650,000.00       52.00      2.00            2.65
# 75%           14.00   6,800,000.00       69.90      3.00            2.80
# max           50.00 763,000,000.00      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23,613.00    21,796.00 23,699.00     21,421.00 12,180.00
# mean          10.67        34.46      5.89         10.57      1.15
# std            6.60        22.03      4.89          5.91      1.07
# ...

# %% [markdown]
# **<font color='Tomato'> Для выявления и обработки неправдоподобных значений смотрим на значения в min(минимальные) max (максимальные). </font>**
#
# -**total_area** - <font color='Salmon'>общая площадь</font>  квартиры. Максимальное значение 900 кв.м. На первый взгляд такая цифра кажется нереальной для жилой квартиры, но на всякий случай я решила проверить, бывают ли такие квартиры. Поиск на циане с сортировкой по площади квартиры по убыванию дал такой результат: площадь самой большой квартиры в [Москве](https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&region=1&room6=1&sort=area_order)
# из выставленных на продажу составляет 2180 кв.м.
# И это при том, что комнат там 6 (они все огромной площади). Поэтому данные о квартире площадью 900 метров и <font color='Salmon'>комнатностью</font>  19 (столбец **rooms**) - вполне правдоподобны на фоне обьявлений Циана. Если посмотреть обьявления не только по Москве, а и по
# [Санкт-Петербургу](https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&region=2&room6=1&sort=area_order), то и там найдутся квартиры площадью 900 кв.м. и выше. Что касается правдоподобности указанного количества комнат, то судя по описанию  [этого обьявления](https://spb.cian.ru/sale/flat/264711689/), данные вполне правдоподобны с учетом площади в 900 метров.
#
# -**ceiling_height** - <font color='Salmon'>высота потолков</font> . С такими данными уже все сложнее. На первый взгляд, это кажется неправдоподобным. Максимальная высота потолков из описаний реальных обьектов с самой большой площадью - 15 метров (если это трехуровневый таунхаус, то это суммарная высота всех трех уровней). Поэтому я предполагаю, что это ошибка. Хотели указать 10 комнат, но опечатались и написали лишний ноль. Все строки, где потолки выше 15 метров, удалим из датасета.
#
# -**floors_total** - <font color='Salmon'>общая этажность дома</font>  и **floor** -  <font color='Salmon'>этаж, на котором расположена продаваемая квартира</font>  (столбец , в котором максимальное значение - 33 этажа). В Петербурге нет дома высотой в 60 этажей. [Самое высокое здание из достроенных - 42 этажа](https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D1%81%D0%B0%D0%BC%D1%8B%D1%85_%D0%B2%D1%8B%D1%81%D0%BE%D0%BA%D0%B8%D1%85_%D0%B7%D0%B4%D0%B0%D0%BD%D0%B8%D0%B9_%D0%A1%D0%B0%D0%BD%D0%BA%D1%82-%D0%9F%D0%B5%D1%82%D0%B5%D1%80%D0%B1%D1%83%D1%80%D0%B3%D0%B0). Выше этого дома есть только один - 88 этажей, но он еще не заселен (ведутся отделочные работы). Поэтому все дома выше 42 этажей удалим.
#
# -**living_area** - <font color='Salmon'>жилая площадь</font>  - величиной в 409 кв.м. - вполне реальная, учитывая вышеупомянутые общие площади квартир и в 900 кв.м, и в 2180 кв.м.
#
# -**balcony** - <font color='Salmon'>число балконов</font>  - максимальное количество 5. И это еще не предел, [в некоторых квартирах их бывает и 10.](https://spb.cian.ru/sale/flat/218657555/)
#
# -**kitchen_area** - <font color='Salmon'>площадь кухни</font> , максимальное значение - 112 кв.м. В квартире площадью 900 кв.м. это не удивительно.
#
# -**airports_nearest** - <font color='Salmon'>расстояние до ближайшего аэропорта</font> , максимальное значение 84869 метров, или 84 километра. Вот это уже <font color='red'>неправдоподобное значение</font> .
# Обнаружила я это следующим образом:  [в 2гисе](https://2gis.ru/spb/geo/5348647327760881/30.316522%2C59.962329?m=30.128674%2C59.933103%2F9.28&ruler=29.508081%2C60.201366%7C30.270575%2C59.799284) измерила расстояние от аэропорта "Пулково" (единственный действующий аэропорт города, остальные не работают, либо находятся далеко от города, еще дальше, чем Пулково) (находится в южной части города) до самой отдаленной от аэропорта точки города, находящейся на северо-западе города. Получилось [61 км](https://disk.yandex.ru/i/vabY-O0d21LXTA)
#
# -**cityCenters_nearest** -<font color='Salmon'>расстояние до центра</font>  - 65968 метров, или 65 км (можно округлить до 66) - тоже <font color='red'>неправдоподобное значение</font> . . Как упоминалось выше, расстояние от одного конца города до другого по прямой получается [61 км](https://disk.yandex.ru/i/vabY-O0d21LXTA). Расстояние от одной окраины до центра, соответственно, должно быть примерно в 2 раза меньше (с учетом того, что разные окраины находятся на разной удаленности от центра).
#
# -**parks_around3000** — <font color='Salmon'>число парков в радиусе 3 км</font> . Минимальное значение - 1, максимальное - 3. Правдоподобно.
#
# -**parks_nearest** — <font color='Salmon'>расстояние до ближайшего парка (м)</font> . Минимум - 1 метр, максимум - 3190 метров, или 3,2 км. Правдоподобно.
#
# -**ponds_around3000** — <font color='Salmon'>число водоёмов в радиусе 3 км</font> . Минимум - 0, максимум - 3. Правдоподобно.
#
# -**ponds_nearest** — <font color='Salmon'>расстояние до ближайшего водоёма (м)</font> . Минимум - 13 метров, максимум - 1344 метра, или 1,3 км. Правдоподобно.
#
# -**days_exposition** — <font color='Salmon'>сколько дней было размещено объявление</font>  (от публикации до снятия). Минимум - 1 день, максимум - 1580 дней, или 4 года и 4 месяца. [Правдоподобно](https://blog.domclick.ru/post/predydushie-khozyaeva-ne-mogli-prodat-kvartiru-8-let)

# %%
flats.index
# Out:
# RangeIndex(start=0, stop=23699, step=1)

# %% [markdown]
# ### **<font color='LightSalmon'> Выводы </font>**
#
# 1. Неправдоподобных данных мало по сравнению с правдоподобными.
# 2. Неправдоподобные значения обнаружены в столбцах: **airports_nearest** - <font color='blue'>расстояние до ближайшего аэропорта</font>  максимальное значение 84869 метров, или 84 километра и **cityCenters_nearest** -<font color='blue'>расстояние до центра</font>  - максимальное значение  65968 метров, или 65 км. Я предположила, что данные указаны не в метрах, а в сантиметрах (По аналогии с данными предыдущего проекта о надежности заемщиков, где количество отработанных дней было указано не в днях, а в часах, и потом пришлось переводить часы в дни), и при проверке подобной гипотезы я поняла, что она неверна: если перевести 84869 и 65968 метров в сантиметры, то получится 848 метров и 659 метров. Для проверки данной гипотезы я измерила расстояние в 2 гисе (электронная онлайн-карта городов России) от аэропорта "Пулково" до ближайших жилых домов и получилось расстояние в 1,7 км. Что касается остальных данных - они были проверены на правдоподобность.
# 3. Очень много пропусков - и по количеству столбцов (больше половины от всего числа столбцов), и по количеству строк (в разных столбцах разные количество пропущенных значений в строках). Их необходимо заполнять средними значениями или медианами.

# %% [markdown]
# ## **<font color='LightCoral'> Предобработка данных </font>**

# %% [markdown]
# **1. Определите и изучите пропущенные значения:**
#
# - Для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать.
#
# - Заполните пропуски, где это уместно. Опишите, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения.
#
# - Укажите причины, которые могли привести к пропускам в данных.
#
# **2. Приведите данные к нужным типам:**
# Поясните, в каких столбцах нужно изменить тип данных и почему.

# %%
# еще одна идея по подсчету пропусков. оставлю на всякий случай

flats.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Здесь мы видим, в каких столбцах пропуски есть, а в каких - нет.
# Приходим к выводу, что больше половины столбцов имеют пропуски.

# %%
# выведем на экран только те столбцы, которые имеют пропуски в порядке убывания

all_skips = flats.isna().sum().to_frame(name="nans").query("nans > 0")["nans"]

all_skips.sort_values(ascending=False)
# Out:
# is_apartment           20924
# parks_nearest          15620
# ponds_nearest          14589
# balcony                11519
# ceiling_height          9195
# airports_nearest        5542
# cityCenters_nearest     5519
# ponds_around3000        5518
# parks_around3000        5518
# days_exposition         3181
# kitchen_area            2278
# living_area             1903
# floors_total              86
# locality_name             49
# Name: nans, dtype: int64

# %%
all_skips.count()
# Out:
# 14

# %% [markdown]
# Количество столбцов с пропусками - 14. Это больше половины столбцов (всего их 22).

# %% [markdown]
# Итак, благодаря сортировке пропусков по убыванию мы видим, в каких столбцах больше всего пропусков, а в каких- меньше всего. Во многих случаях подобная сортировка помогает нам понять причины пропусков, а также возможную связь одних пропусков с другими.

# %%
flats.query('rooms == ["2"]')
# Out:
#        total_images    last_price  total_area first_day_exposition  rooms  \
# 2                10  5,196,000.00       56.00  2015-08-20T00:00:00      2
# 4                 2 10,000,000.00      100.00  2018-06-19T00:00:00      2
# 7                 5  7,915,000.00       71.60  2019-04-18T00:00:00      2
# 11                9  3,300,000.00       44.00  2018-08-27T00:00:00      2
# 12               10  3,890,000.00       54.00  2016-06-30T00:00:00      2
# ...             ...           ...         ...                  ...    ...
# 23681            13  5,250,000.00       43.00  2018-05-11T00:00:00      2
# 23690             3  5,500,000.00       52.00  2018-07-19T00:00:00      2
# 23691            11  9,470,000.00       72.90  2016-10-13T00:00:00      2
# 23696            18  2,500,000.00       56.70  2018-02-11T00:00:00      2
# 23697            13 11,475,000.00       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# **<font color='blue'>ПРИЧИНЫ ПРОПУСКОВ</font> И <font color='teal'>И СПОСОБ ИХ ОБРАБОТКИ</font>:**
#
#
# **is_apartment** - 20924 пропусков в столбце <font color='blue'>"апартаменты"</font>. Не все люди знают разницу между статусами помещений "квартира" и "апартаменты", поэтому могли не указать. Либо могли специально не указать, является ли помещение апартаментами для того, чтобы это скрыть, чтобы продаваемый обьект казался более привлекательным вариантом для потенциального покупателя.  <font color='teal'> подумаем над тем, как и чем  заполнить эти пропуски. </font>
#
#
# **parks_nearest** - 15620 пропусков в столбце <font color='blue'>"расстояние до ближайшего парка (м)"</font>. Могли не указать. Во-первых, это не обязательный параметр. Во-вторых, он повышает привлекательность продаваемой квартиры только в случае, если парк находится недалеко. Предполагаю, что не указали его как раз в тех квартирах, которые расположены далеко от парка. <font color='teal'>заполнять пропуски не будем. Но если нам все же понадобится заполнить эти пропуски, то можно заполнить их значениями "нет" (в смысле - нет парка поблизости)  </font>. В дальнейшем при заполнении пропусков я буду использовать именно эту логику - что преимущества квартиры (и не только квартиры, а и любого другого товара) продавцы и риэлторы всегда стараются показывать, делать на них особый акцент, а недостатки - маскировать, задвигать на задний план, либо вообще прятать. В этом есть прямая заинтересованность продавцов квартиры  потому, что чем больше у квартиры достоинств и меньше недостатков, тем быстрее и дороже ее можно продать.
#
# **ponds_nearest** - 14589 пропусков в столбце <font color='blue'>"расстояние до ближайшего водоёма (м)"</font> . Аналогично с предыдущим пунктом. <font color='teal'> заполнять пропуски не будем. Но если нам все же понадобится заполнить эти пропуски, то можно заполнить их значениями "нет" (в смысле - нет парка поблизости) </font>
#
# **balcony**  - 11519 пропусков в столбце <font color='blue'>"число балконов"</font> . Не указали потому, что в этих квартирах нет балкона. Если бы он был - его бы указали хотя бы потому, что наличие балкона повышает привлекательность квартиры, а следовательно - ее стоимость. <font color='teal'>заполним значениями "нет"</font>
#
# **ceiling_height** - 9195 пропусков в столбце <font color='blue'>"высота потолков (м)"</font> . Не написали в квартирах, где потолки стандартной высоты - 2,4 или 2,5 метров. Потому, что высокие потолки (например, сталинки или элитное жилье, где высота потолков 3-4 метра) - это один из факторов, которые увеличивает привлекательность и  стоимость квартиры. <font color='teal'>заполним средними значениями</font> , т.к. в большинстве квартир высота потолков стандартная, 2,4-2,5 метров. Есть еще второй вариант - заполнить данными о высоких потолках в центральных районах и данными о стандартной высоте потолков - в районах за пределами центра, но я так делать не буду, т.к. первый вариант (где высота потолков влияет на цену и такие квартиры при прочих равных имеют преимущества перед другими квартирами) кажется более реалистичным по логике "достоинства - выставлять напоказ, недостатки - прятать".
#
# **airports_nearest** - 5542 пропусков в столбце <font color='blue'>"расстояние до ближайшего аэропорта в метрах (м)"</font>. Не обязательный параметр, поэтому могли не указать. Предполагаю, что это в большей степени характерно для обьектов, находящихся в центральной, северо-восточной и северо-западной части города потому, что в таком случае расстояние получится очень большим. <font color='teal'>заполним средними показателями</font> т.к. люди не каждый день летают на самолетах. Такой параметр имеет значение только для работников аэропорта, но их от общего числа населения очень маленький процент, а точнее - доля процента
#
# **cityCenters_nearest** - 5519 пропусков в столбце <font color='blue'>"расстояние до центра города (м)"</font>. Во-первых, это не обязательный параметр, во-вторых, могли не указать в первую очередь для тех обьектов, которые находятся далеко от центра города. Потому, что близость к центру города увеличивает спрос на квартиру и заодно ее стоимость. Этот параметр важен, так как людей, которые ездят на метро/личном авто в центр и обратно, довольно много. И удаленность от центра существенно влияет на цену, причем наблюдается прямая корелляциия между удаленностью от центра и стоимостью квартиры, и это тенденция характерна для многих городов. Соответственно, спрос на такие квартиры выше, цена дороже и срок продажи меньше. <font color='teal'> ????</font>
#
# **ponds_around3000** - 5518 пропусков в столбце <font color='blue'>"число водоёмов в радиусе 3 км"</font>. Предполагаю, что это не указано для обьектов, находящихся далеко от парков и прудов. При прочих равных квартиры в пешей доступности от парков и прудов пользуются большим спросом у потенциальных покупателей, чем квартиры, находящиеся далеко от парков и прудов. <font color='teal'>пропуски заполнять не будем</font>
#
# **parks_around3000** - 5518 пропусков в столбце <font color='blue'>"число парков в радиусе 3 км"</font>. См.предудыщуий пункт. <font color='teal'>пропуски заполнять не будем</font>
#
# **days_exposition** - 3181 пропусков в столбце <font color='blue'>"сколько дней было размещено объявление (от публикации до снятия)"</font>. Данные могли не выгрузиться. Потому, что на том же Циане дата публикации и снятия обьявления всегда фиксируется. Поэтому эти данные должны быть в 100% случаев. Таких данных, по сравнению с перечисленными выше, немного - всего 13%, поэтому <font color='teal'> заполнять пропуски не будем</font>
#
# **kitchen_area** - 2278 пропусков в столбце <font color='blue'>"площадь кухни в квадратных метрах (м²)"</font>. Предполагаю, что могли не указать в нескольких случаях. 1. Если это квартира-студия 2. Если кухня очень маленькая (в хрущевках и квартирах гостиничного типа) и это является минусом продаваемой квартиры   <font color='teal'>заполним значениями в 4-5 кв.м. (средние значения площади кухни для маленьких квартир)</font> в случае, если последняя гипотеза подтвердится.
#
# **living_area** - 1903 пропусков в столбце <font color='blue'>"жилая площадь в квадратных метрах (м²)"</font>. Важный параметр, один из главных факторов ценообразования квартиры. Предполагаю, что могла быть не указана потому, что неизвестна в случае, если это квартира-студия и там невозможно отделить зону кухни и ее площадь от зоны комнаты и ее площади. Либо данные не были выгружены из системы. <font color='teal'>посмотрим, для каких квартир это характерно больше всего и примем решение, изучив данные по квартирам, в которых не указана жилая площадь</font>
#
# **floors_total** - 86 пропусков в столбце <font color='blue'>"всего этажей в доме"</font>. Поскольку это один из обязательных параметров при заполнении обьявления на продажу квартиры, то скорее всего, данные не были выгружены из системы.    <font color='teal'> заполним средними значениями этажности по району</font> потому, что в центре Санкт-Петербурга этажность домов в среднем меньше, чем на окраинах.
#
# **locality_name** - 49 пропусков в столбце <font color='blue'>"название населённого пункта"</font>. Аналогично с предыдущим пунктом.   <font color='teal'>заполнять не будем</font> в связи с тем, что таких данных 0,2% от общего числа.

# %% [markdown]
# Как я уже писала выше, пропусков много и их надо заполнить.

# %%
display('Количество пропусков в столбце is_apartment:', flats['is_apartment'].isna().sum())
# Out:
# 'Количество пропусков в столбце is_apartment:'
# 20924

# %%
flats['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
quantity_strings_is_apartment_true = len(flats[flats['is_apartment'] == True])

# %%
quantity_strings_is_apartment_true
# Out:
# 50

# %% [markdown]
# Во всем датафрейме из более, чем 23 тысяч строк, всего в 50 обьектах тип недвижимости был указан как "апартаменты".
#
# По данным [Циан](https://spb.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&region=2&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room9=1), на сегодняшний день в Санкт-Петербурге выставлено на продажу 58253 квартир, из которых [апартаменты](https://spb.cian.ru/cat.php?apartment=1&deal_type=sale&engine_version=2&offer_type=flat&region=2&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room9=1) -  2736.
# <font color='purple'> Процент апартаментов от общего числа продаваемых квартир - 4%.</font>

# %%
# делим количество апартаментов на общее количество квартир, получаем процент апартаментов от общего числа квартир 
# по данным циан

cian = 2736/58253

# %%
len(flats.index)
# Out:
# 23699

# %%
# получим количество строк в датафрейме, сохраним в переменную

len_flats = len(flats.index)

# %%
len_flats
# Out:
# 23699

# %%
# делим количество апартаментов на общее количество квартир, получаем процент апартаментов от общего числа квартир 
# по данным нашего датасет

our_quantity_of_aparts = quantity_strings_is_apartment_true / len_flats

# %%
our_quantity_of_aparts
# Out:
# 0.0021097936621798387

# %% [markdown]
# В первом случае (данные Циан) мы получаем 4%, во втором случае - 0,2%. Данные нашего датасета неправдоподобны потому, что сильно отличаются от данных Циан. Посчитаем, во сколько раз эти данные разнятся:

# %%
cian / our_quantity_of_aparts
# Out:
# 22.261673733541624

# %% [markdown]
# Статистика Циан по количеству апартаментов отличается от нашей в 22 раза. Это огромная разница, которая еще раз подчеркивает то, что у нас данные не соотносятся с действительностью.

# %%
display('Количество пропусков в столбце "расстояние до аэропорта":', flats['airports_nearest'].isna().sum())
flats['airports_nearest'].value_counts()

display('Количество пропусков в столбце "расстояние до центра":', flats['cityCenters_nearest'].isna().sum())
flats['cityCenters_nearest'].value_counts()

display('Количество пропусков в столбце "расстояние до ближайших прудов":', flats['ponds_around3000'].isna().sum())
flats['ponds_around3000'].value_counts() 

display('Количество пропусков в столбце "расстояние до ближайшего парка":', flats['parks_around3000'].isna().sum())
flats['parks_around3000'].value_counts()
# Out:
# 'Количество пропусков в столбце "расстояние до аэропорта":'
# 5542
# 'Количество пропусков в столбце "расстояние до центра":'
# 5519
# 'Количество пропусков в столбце "расстояние до ближайших прудов":'
# 5518
# 'Количество пропусков в столбце "расстояние до ближайшего парка":'
# 5518
# 0.00    10106
# 1.00     5681
# 2.00     1747
# 3.00      647
# Name: parks_around3000, dtype: int64

# %% [markdown]
# Есть гипотеза, что пропуски в столбцах **airports_nearest**, **cityCenters_nearest**, **ponds_around3000** и **parks_around3000** - это одни и те же строки. Проверим:

# %%
four_columns_with_nan = ('пропуски в airports_nearest, в cityCenters_nearest, ponds_around3000 и parks_around3000 в {} строках'.
      format(flats.query('airports_nearest != airports_nearest and cityCenters_nearest != cityCenters_nearest and ponds_around3000 != ponds_around3000 and parks_around3000 != parks_around3000').shape[0]))

print(four_columns_with_nan)
# Out:
# пропуски в airports_nearest, в cityCenters_nearest, ponds_around3000 и parks_around3000 в 5518 строках

# %% [markdown]
# Столбец "расстояние до центра" (cityCenters_nearest) нельзя заполнить средним/медианой потому, что это будет некорректно. Из-за больших расстояний разных районов до центра погрешности будут такими же большими. Если бы у нас был столбец "район" (или ближайшая станция метро - на циане у большинства продаваемых квартир ближайшее метро указано. Значит, и столбец с указанием станций метро можно было бы сделать), можно было бы измерить вручную в 2гис расстояние от каждого района для центра, а потом создать функцию, где каждому району присваивалось бы определенное расстояние от центра. Но таких данных у нас нет. **Поэтому оставим эти пропуски, как есть.**

# %% [markdown]
# Очистим данные столбца **"ceiling_height"** от неправдоподобных значений, т.е. от данных, где потолок выше 15 метров. Я абсолютно точно знаю, что такие квартиры существуют - я сама лично в них была, и неоднократно. Это, как правило, трех- или четырехуровневые пентахусы. Таких квартир немного, но они есть.

# %%
print("Количество квартир с потолками выше 4 метров:", flats[flats['ceiling_height'] >= 4].count()[0])
# Out:
# Количество квартир с потолками выше 4 метров: 114

# %% [markdown]
# Сталинки и элитное жилье имеют высоту потолков до 4 метров. Все, что выше 4 метров - это пентхаусы.
#
# 114 пентхаусов из 23699 квартир - это вполне правдоподобная цифра. Их действительно очень мало от общего числа, поэтому оставим, как есть.

# %%
print("Количество квартир с потолками выше 15 метров:", flats[flats['ceiling_height'] > 15].count()[0])
# Out:
# Количество квартир с потолками выше 15 метров: 23

# %%
flats.drop(flats.loc[flats['ceiling_height'] > 15].index, inplace=True)

# %% [markdown]
# проверим, удалились ли квартиры с потолками выше 15 метров:

# %%
print("Количество квартир с потолками выше 15 метров:", flats[flats['ceiling_height'] > 15].count()[0])
# Out:
# Количество квартир с потолками выше 15 метров: 0

# %%
flats['ceiling_height'].isnull().sum()
# Out:
# 9195

# %%
flats['ceiling_height'].value_counts()
# Out:
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
# 2.80     993
#         ...
# 3.59       1
# 4.80       1
# 2.49       1
# 4.06       1
# 4.14       1
# Name: ceiling_height, Length: 174, dtype: int64

# %% [markdown]
# 2.50 или 2 метра 50 см - самая распространенная высота потолков в квартирах. Этим значением и заполним пропуски.

# %%
flats['ceiling_height'].median()
# Out:
# 2.65

# %%
flats['ceiling_height'].fillna(flats['ceiling_height'].median(), inplace=True)

# %% [markdown]
# Проверим, не осталось ли незаполненных пропусков:

# %%
flats['ceiling_height'].isna().sum()
# Out:
# 0

# %%
flats['ceiling_height'].value_counts()
# Out:
# 2.65    9871
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
#         ...
# 4.14       1
# 3.59       1
# 4.80       1
# 3.93       1
# 3.58       1
# Name: ceiling_height, Length: 174, dtype: int64

# %% [markdown]
# здесь мы видим, что количество квартир с высотой потолков 2,5 метра увеличилось с 3515 до 12710. Ничего удивительного в таком перекосе (данных с такой высотой потолка теперь почти половина от всех данных датасета) я не вижу потому, что большая часть жилого фонда многих городов РФ - хрущевки, брежневки, новостройки и прочие дома, построенные после 1950 г. Дома с высокими потолками - это либо сталинки, либо дореволюционные дома. Учитывая их активный снос по программам ренновации/расселения ветхого жилья, то их остается все меньше и меньше. За исключением случаев, когда тот или иной дом признан памятником культурного наследия.

# %% [markdown]
# Сделаем категоризацию данных по удаленности от центра. В связи с тем, что часть пропусков нам заполнить не удалось, то для части квартир расстояние от центра осталось неизвестным.
#
#
# Наши категории:
#
# 0-2км от центра (категория 'самый центр');
# 2-5км от центра (категория 'центр');
# 5-17км от центра (категория 'близко к центру');
# меньше 17км от центра (категория 'пгт').
# Так выглядит логично: 0-2,5 км - квартира у Дворцовой, 2-5 км - квартира на ВО, 5-17км - квартира на Парнасе или в Купчино. > 17км - за КАДом.
#
# Напишем под это функцию:

# %%
def fillna_ceiling_height(row):
    if row['cityCenters_nearest'] < 2500:
        return 'самый центр'
    elif row['cityCenters_nearest'] < 5000:
        return 'центр'
    elif row['cityCenters_nearest'] < 17000:
        return 'в пределах города'
    elif row['cityCenters_nearest'] >= 17000:
        return 'область'

# %% [markdown]
# Применяем функцию:

# %%
flats['fromcenter_category'] = flats.apply(fillna_ceiling_height, axis=1)

# %% [markdown]
# Результат:

# %%
flats[['locality_name', 'cityCenters_nearest', 'fromcenter_category']].head(10)
# Out:
#                locality_name  cityCenters_nearest fromcenter_category
# 0            Санкт-Петербург            16,028.00   в пределах города
# 1             посёлок Шушары            18,603.00             область
# 2            Санкт-Петербург            13,933.00   в пределах города
# 3            Санкт-Петербург             6,800.00   в пределах города
# 4            Санкт-Петербург             8,098.00   в пределах города
# 5  городской посёлок Янино-1                  nan                None
# 6          посёлок Парголово            19,143.00             область
# 7            Санкт-Петербург            11,634.00   в пределах города
# 8             посёлок Мурино                  nan                None
# 9            Санкт-Петербург            15,008.00   в пределах города

# %%
flats.groupby('fromcenter_category')['ceiling_height'].mean().sort_values(ascending=False).to_frame()
# Out:
#                      ceiling_height
# fromcenter_category
# самый центр                    3.07
# центр                          2.97
# в пределах города              2.69
# область                        2.65

# %%
print('Количество пропусков в столбце "количество дней экспозиции (продажи) квартиры":', flats['days_exposition'].isna().sum())
# Out:
# Количество пропусков в столбце "количество дней экспозиции (продажи) квартиры": 3175

# %% [markdown]
# Для заполнения пропусков в этом столбце среднее значение или медиана подойдет потому, что это будет корректное заполнение пропусков. Корректным оно будет потому, что автоматическое продление обьявления о продаже квартиры на Циан - это платная услуга. Что касается бесплатных обьявлений, то их либо продлевать вручную, либо размещать новое обьявление. Поэтому ситуация, когда квартира давно продана, а обьявление продолжает "висеть" на сайте месяцами, крайне маловероятно - ведь за это списываются деньги, определенная сумма ежемесячно. Поэтому смело заполняем этот столбец средними показателями:

# %% [markdown]
# Далее работаем с **days_exposition** — сколько дней было размещено объявление (от публикации до снятия)

# %%
flats['days_exposition'].value_counts()
# Out:
# 45.00       880
# 60.00       538
# 7.00        233
# 30.00       208
# 90.00       204
#            ...
# 1,110.00      1
# 1,049.00      1
# 951.00        1
# 693.00        1
# 773.00        1
# Name: days_exposition, Length: 1141, dtype: int64

# %%
flats['days_exposition'].mean()
# Out:
# 180.92761328715673

# %%
flats['days_exposition'].fillna(flats['days_exposition'].mean(), inplace=True)

# %%
# проверяем, остались ли незаполненные пропуски

flats['days_exposition'].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски в столбцах **kitchen_area** - площадь кухни и  **living_area** - жилая площадь

# %%
print('Количество пропусков по площади кухни:', flats['kitchen_area'].isnull().sum())
print('Количество пропусков по жилой площади:', flats['living_area'].isnull().sum())
# Out:
# Количество пропусков по площади кухни: 2274
# Количество пропусков по жилой площади: 1903

# %% [markdown]
# Есть гипотеза, что информация по площади кухни не указана в квартирах-студиях, где кухня и жилая комната никак не разьединены, т.е. являются одним помещением. Как правило, вместо отдельно площади кухни и отдельно жилой площади там указывается площадь суммарно кухонной и жилой зоны. Проверим:

# %%
flats.query('rooms == 0')[['kitchen_area', 'living_area']].isna().sum()
# Out:
# kitchen_area    196
# living_area      14
# dtype: int64

# %% [markdown]
# Определим долю площади кухни от общей площади:

# %%
kitchen_area_ratio = flats['kitchen_area'] / flats['total_area']

# %% [markdown]
# Среднее значение доли  площади кухни от общей площади:

# %%
kitchen_area_ratio.mean()
# Out:
# 0.18735759074918268

# %% [markdown]
# Доля площади кухни от общей площади - 18%

# %% [markdown]
# Посмотрим долю жилой площади от общей и ее среднее значение:

# %%
living_area_ratio = flats['living_area'] / flats['total_area']
living_area_ratio.mean()
# Out:
# 0.5647048355949961

# %% [markdown]
# Доля жилой площади от общей - 56%.

# %% [markdown]
# Заменим пропущенные значения площади кухни на среднее значение доли площади кухни от общей (18%):

# %%
flats['kitchen_area'].fillna(kitchen_area_ratio.mean(), inplace=True)

# %% [markdown]
# Проверим, все ли заполнилось:

# %%
flats['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Вывод: к студиям относится не более 10% от всех пропусков в столбцах "площадь кухни" и "жилая площадь". Гипотеза не подтвердилась. Значит, причина другая.

# %% [markdown]
# Можно было бы получить площадь кухни следующим образом: **flats['kitchen_area'] = flats['total_area'] - flats['living_area']**, но такой способ не подойдет. Есть один нюанс. Если отнять жилую площадь квартиры от общей, то получится не только площадь кухни, но и площадь санузлов, гардеробных, кладовок, и так далее. На примере моей квартиры: общая площадь 41 метр, жилая площадь - 25 метров (комната 12 метров плюс комната 13 метров). 41-25 = 16 метров. Но погрешность получается большая (более, чем в 2 раза) потому, что кухня у меня не 16, а 7 метров. 16 метров - это площадь и кухни, и санузлов, и гардеробной. Будь к нас столбцы, где были бы указаны площади санузлов и кладовок/гардеробных/встроенных шкафов, то так можно было бы сделать. **Придется оставить пропуски без заполнения.**

# %%
print("Количество квартир с домах с этажностью больше 42:", flats[flats['floors_total'] > 42].count()[0])
# Out:
# Количество квартир с домах с этажностью больше 42: 2

# %% [markdown]
# Таких квартир всего 2, поэтому можно удалить.

# %%
flats.drop(flats.loc[flats['floors_total'] > 42].index, inplace=True)

# %%
print('Количество пропусков по floors_total:', flats['floors_total'].isna().sum())
# Out:
# Количество пропусков по floors_total: 86

# %% [markdown]
# Выведем на экран долю пропусков по столбцу "всего этажей в доме" от общего числа строк в данном столбце:

# %%
flats['floors_total'].isna().sum() * 100 / len(flats['floors_total'])
# Out:
# 0.0

# %% [markdown]
# **Вывод:** В столбце "всего этажей в доме" пропусков меньше 1%. Следовательно, можно удалить:

# %%
flats['floors_total'].dropna(inplace=True)

# %% [markdown]
# Проверим, все ли удалилось:

# %%
flats['floors_total'].isna().sum()
# Out:
# 0

# %%
flats['floors_total'].value_counts()
# Out:
# 5.00     5778
# 9.00     3759
# 16.00    1376
# 12.00    1362
# 4.00     1199
# 10.00    1173
# 25.00    1074
# 6.00      913
# 17.00     832
# 3.00      667
# 7.00      592
# 14.00     552
# 18.00     505
# 24.00     468
# 8.00      390
# 2.00      381
# 15.00     365
# 23.00     352
# 19.00     339
# 22.00     286
# 20.00     271
# 13.00     229
# 11.00     203
# 27.00     164
# 21.00     158
# 26.00     124
# 1.00       25
# 35.00      24
# 28.00      21
# 36.00       2
# 29.00       1
# 33.00       1
# 37.00       1
# 34.00       1
# Name: floors_total, dtype: int64

# %% [markdown]
# Больше всего продаваемых квартир расположено в домах с 5 этажами. После них идут 9-этажки.

# %%
flats['floors_total'].mean()
# Out:
# 10.671443106664405

# %%
flats['floors_total'].median()
# Out:
# 9.0

# %% [markdown]
# Заполним отсутствующие значения медианой и проверим, заполнилось ли:

# %%
flats['floors_total'].fillna(flats['floors_total'].median(), inplace=True)

# %%
flats['level'] = np.where(flats['floor'] == flats['floors_total'], 'последний', flats['level'])

# %% [markdown]
# Выведем на экран строки, где продаваемая квартира находилась на последнем этаже:

# %%
display(flats[flats['level'] == 'последний'])
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12               10        3890       54.00           2016-06-30      2
# 13               20        3550       42.80           2017-07-01      2
# 23               11        2950       32.00           2016-10-29      1
# 36               13        3790       45.00           2017-01-25      2
# 43               13        9330       48.00           2017-01-10      2
# ...             ...         ...         ...                  ...    ...
# 23641             3        3100       30.00           2018-03-28      1
# 23644             7        4990       62.50           2018-04-26      2
# 23648            14       10100       78.00           2017-05-12      3
# 23660             1        2950       53.60           2018-02-01      2
# 23685            15        2490       31.00           2019-01-24      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# На первый взгляд кажется, что все заполнилось правильно и некорректно заполненных строк не видно. Но все же капнем глубже:

# %% [markdown]
# Посмотрим, есть ли квартиры, где этаж продаваемой квартиры больше, чем общая этажность дома:

# %%
np.where(flats['floor'] > flats['floors_total'])
# Out:
# (array([  456,  2390,  2844,  3029,  3435,  4614,  4844,  5140,  5181,
#          5776,  5949,  6021,  7912,  8468,  9013, 10002, 10016, 10047,
#         10520, 10971, 11117, 13425, 13609, 14081, 14251, 14512, 16577,
#         16835, 17482, 19434, 20128, 20718, 21253, 21630, 21732, 22633,
#         23565]),)

# %% [markdown]
# Посчитаем кол-во квартир, где заполнение медианным значением этажа выдало нам ошибку в виде того, что этаж продаваемой квартиры оказался выше общей этажности дома:

# %%
print("кол-во квартир, где этаж > всего этажей в доме", flats[flats['floors_total'] < flats['floor']].count()[0])
# Out:
# кол-во квартир, где этаж > всего этажей в доме 37

# %% [markdown]
# Проанализируем долю таких заполненных данных:

# %%
flats[flats['floors_total'] < flats['floor']].count()[0] / len(flats['floors_total'])
# Out:
# 0.0015628960040550816

# %% [markdown]
# Как мы видим, таких данных меньше 1%. Можно удалить:

# %%
flats.drop(flats.loc[flats['floors_total'] < flats['floor']].index, inplace=True)

# %% [markdown]
# Проверим, удалилось ли:

# %%
np.where(flats['floor'] > flats['floors_total'])
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# Проверим кол-во пропусков по этому столбцу:

# %%
print('Количество NaN по floors_total:', flats['floors_total'].isna().sum())
# Out:
# Количество NaN по floors_total: 0

# %% [markdown]
# Теперь обработаем пропуски в столбце **locality_name** - название населенного пункта. Сначала посмотрим, сколько в каких населенных пунктах у нас больше всего обьектов:

# %%
flats['locality_name'].value_counts()
# Out:
# Санкт-Петербург      15707
# посёлок Мурино         520
# посёлок Шушары         440
# Всеволожск             398
# Пушкин                 369
#                      ...
# деревня Лаврики          1
# поселок Почап            1
# деревня Хязельки         1
# поселок Рабитицы         1
# поселок Кирпичное        1
# Name: locality_name, Length: 363, dtype: int64

# %% [markdown]
# посмотрим, сколько столбцов с пропусками в локации имеют указанное расстояние до центра:

# %%
print('Количество пропусков по locality_name:', flats['locality_name'].isna().sum())
flats[(flats['locality_name'].isna())][['locality_name', 'cityCenters_nearest']].head(10)
# Out:
# Количество пропусков по locality_name: 49
#      locality_name  cityCenters_nearest
# 1097           NaN             4,258.00
# 2033           NaN                  nan
# 2603           NaN            17,369.00
# 2632           NaN            17,369.00
# 3574           NaN             8,127.00
# 4151           NaN             3,902.00
# 4189           NaN             3,039.00
# 4670           NaN             5,382.00
# 5343           NaN             9,538.00
# 5707           NaN            16,788.00

# %% [markdown]
# Проанализируем долю пропусков по столбцу "locality_name":

# %%
flats['locality_name'].isna().sum() * 100 / len(flats['locality_name'])
# Out:
# 0.10153572788424926

# %%
display('Пропуски в столбце "название населённого пункта"'':', flats['locality_name'].isna().sum())
# Out:
# 'Пропуски в столбце "название населённого пункта":'
# 24

# %% [markdown]
# Вывод: пропусков меньше 1%, их можно удалить:

# %%
flats['locality_name'].dropna(inplace=True)

# %% [markdown]
# Проверим, удалилось ли:

# %%
flats['locality_name'].isna().sum()
# Out:
# 0

# %%
flats.loc[(flats['locality_name'].isna()) & (flats['cityCenters_nearest'] < 10000), 'locality_name'] = flats.loc[(flats['locality_name'].isnull()) & (flats['cityCenters_nearest'] < 10000), 'locality_name'].fillna('Санкт-Петербург')

# %% [markdown]
# Обновим данные по пропускам:

# %% [markdown]
# Обработка пропусков по столбцу "балконы". Сначала смотрим на то, какие значения у нас вообще есть:

# %%
flats['balcony'].value_counts()
# Out:
# 1.00    4190
# 0.00    3758
# 2.00    3651
# 5.00     301
# 4.00     182
# 3.00      81
# Name: balcony, dtype: int64

# %% [markdown]
# Вывод: неправдоподобных значений по этому столбцу нет (как уже и писала ранее). Поэтому здесь только пропуска заполнить. Считаем количество пропусков:

# %%
print('Количество NaN по floors_total:', flats['floors_total'].isna().sum())
# Out:
# Количество NaN по floors_total: 0

# %%
flats['balcony'].fillna(0, inplace=True)

# %%
# выведем на экран только те столбцы, которые имеют пропуски в порядке убывания

all_skips = flats.isna().sum().to_frame(name="nans").query("nans > 0")["nans"]

all_skips.sort_values(ascending=False)
# Out:
# is_apartment           20911
# parks_nearest          15604
# ponds_nearest          14572
# airports_nearest        5533
# fromcenter_category     5510
# cityCenters_nearest     5510
# ponds_around3000        5509
# parks_around3000        5509
# living_area             1903
# locality_name             24
# Name: nans, dtype: int64

# %%
display('Пропуски в столбце "апартаменты (булев тип)"'':', flats['is_apartment'].isna().sum())
# Out:
# 'Пропуски в столбце "апартаменты (булев тип)":'
# 20874

# %% [markdown]
# Оценим долю пропусков в этом столбце от общего числа строк:

# %%
flats['is_apartment'].isna().sum() * 100 / len(flats)
# Out:
# 0.0

# %% [markdown]
# Доля очень большая - 88% значений не заполнено. Как я уже писала выше со ссылками на подбор обьявлений из Циана по фильтрам "апартаменты - не апартаменты", доля апартаментов от общего числа продаваемых квартир очень мала. Следовательно, все остальные квартиры апартаментами не являются. Заполним отсутствующие данные значением False потому, что тип данных в этом столбце - булевый:

# %%
flats['is_apartment'].fillna(False, inplace=True)

# %%
Проверим, все ли заполнилось:

# %%
flats['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Итоги работы над пропусками:**
#
# Полностью заполнила пропуски в столбцах:
#
# **ceiling_height** - высота потолков
# **days_exposition** - сколько дней было размещено объявление (от публикации до снятия)
# **floors_total** - всего этажей в доме
# **balcony** - число балконов
# столбец **locality_name** частично (заполнено 3/4 пропусков)
#
# Те пропуски, которые остались, заполнить не удалось. О причинах я писала выше.

# %% [markdown]
# ***Приведите данные к нужным типам:
# Поясните, в каких столбцах нужно изменить тип данных и почему.***

# %%
flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23674 entries, 0 to 23698
# Data columns (total 23 columns):
# total_images            23674 non-null int64
# last_price              23674 non-null float64
# total_area              23674 non-null float64
# first_day_exposition    23674 non-null object
# rooms                   23674 non-null int64
# ceiling_height          23674 non-null float64
# floors_total            23674 non-null float64
# living_area             21771 non-null float64
# floor                   23674 non-null int64
# is_apartment            2763 non-null object
# studio                  23674 non-null bool
# open_plan               23674 non-null bool
# kitchen_area            23674 non-null float64
# balcony                 23674 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18141 non-null float64
# cityCenters_nearest     18164 non-null float64
# parks_around3000        18165 non-null float64
# ...

# %% [markdown]
# **Столбцы, в которых изменим типы данных:**
#
# **last_price** - в целое число (нам не нужны копейки в цене. Они нужны были бы, если бы мы работали, например, с базой данных магазина продовольственных товаров);
#
# **total_area** - округлим до 1го знака после запятой (с  такой точностью площадь квартиры указывают в плане БТИ);
#
# **first_day_exposition** - даты переведем в формат datetime;
#
# **ceiling_height** - округлим до 1го знака после запятой (согласитесь, есть разница между потолком 2,4 метра и 2,9 метра);
#
# **floors_total, balcony** - количество этажей - всегда целое число. Не бывает домов с этажностью 5,5 этажей. Меняем на целое число;
#
# **living_area, kitchen_area** - по аналогии с  площадью квартиры  и высотой потолков, то есть оставляем 1 знак после запятой
#
# **airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest** -  расстояния указаны в метрах, переводим в целое число
#
# **days_exposition** - Сколько дней продавали квартиру.  Переводим в целое число.

# %% [markdown]
# **Порядок действий:**
#
# Изменяю формат столбца first_day_exposition на datetime, т.к. нам из этого столбца необходимо добавлять новые столбцы из Шага 3.
# Добавляю новые столбцы из Шага 3 (цена кв.м.; год, месяц, день недели публикации объявления, категории по этажам (первый, последний, другой), сотношение жилой площади и площади кухни с общей площадью).
# Меняю тип данных для всех остальных столбцов, где это необходимо.
# Почему в таком порядке? Чтобы по 2 раза не заниматься изменением данных: сначала в столбцах начальной таблицы, а потом во вновь сформированных.
#
# 1. Изменяю тип данных столбца **first_day_exposition** на datetime:

# %%
flats['first_day_exposition'] = pd.to_datetime(flats['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# 2. Добавляю новых столбцов (Шаг 3 в оригинальном списке задач):
#
# Посчитаем и добавим цену квадратного метра:

# %%
flats['price_of_m2'] = flats['last_price']/flats['total_area']

# %% [markdown]
# Добавим год и месяц размещения объявления:

# %%
flats['year'] = flats['first_day_exposition'].apply(lambda x: x.year)
flats['month'] = flats['first_day_exposition'].apply(lambda x: x.month)

# %% [markdown]
# Добавим день недели публикации объявления:
#
# Сначала проставим день недели в формате числа (1 - понедельник, 7 - воскресенье):

# %%
flats['day'] = flats['first_day_exposition'].apply(lambda x: x.isoweekday())

# %% [markdown]
# Создаем словарь, чтобы изменить значение с чисел на текст (напр., 'суббота'):

# %%
dict_of_weekdays = {1: '1 - понедельник', 2: '2 - вторник', 3: '3 - среда', 4: '4 - четверг', 
                    5: '5 - пятница', 6: '6 - суббота', 7: '7 - воскресенье'}

# %% [markdown]
# Меняем значения:

# %%
flats['day'] = flats['day'].map(dict_of_weekdays)

# %% [markdown]
# Добавим категорию по этажам (варианты — 'первый', 'последний', 'другой'):

# %%
flats['level'] = np.where(flats['floor'] == 1, 'первый', 'другой')
flats['level'] = np.where(flats['floor'] == flats['floors_total'], 'последний', flats['level'])

# %% [markdown]
# Добавим столбцы с соотношением жилой и общей площади, а также с отношением площади кухни к общей:

# %%
flats['living_area_part'] = flats['living_area']/flats['total_area']
flats['kitchen_area_part'] = flats['kitchen_area']/flats['total_area']

# %% [markdown]
# **Столбцы, которые переводим в целое число:**
#
#
# 1.'last_price'
# 2.'floors_total'
# 3.'balcony'
# 4.'airports_nearest'
# 5.'cityCenters_nearest'
# 6.'parks_around3000'
# 7.'parks_nearest'
# 8.'ponds_around3000'
# 9.'ponds_nearest'
# 10.'days_exposition'
# 11.'price_of_m2'

# %% [markdown]
# **Округляем до 1 знака после запятой**
#
# 1.'total_area'
# 2.'ceiling_height'
# 3.'living_area'
# 4.'kitchen_area'
#
# **Округляем до 2 знаков после запятой**
#
# 1.'living_area_part'
# 2.'kitchen_area_part'

# %% [markdown]
# Список столбцов для приведения к целочисленному типу:

# %%
list_to_int = ['last_price', 'floors_total', 'balcony', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000',
               'parks_nearest', 'ponds_around3000', 'ponds_nearest', 'days_exposition', 'price_of_m2']

# %% [markdown]
# Изменяем на целочисленный тип:

# %%
for column in list_to_int:
    flats[column] = flats[flats[column].notnull()][column].astype('int')

# %% [markdown]
# Столбцы, где округляем данные до 1 знака после запятой:

# %%
list_to_float_1 = ['total_area', 'ceiling_height', 'living_area', 'kitchen_area']

# %% [markdown]
# Округляем до 1 знака после запятой:

# %%
for column in list_to_float_1:
    flats[column] = flats[flats[column].notnull()][column].round(1)

# %% [markdown]
# Столбцы, где округляем данные до 2 знаков после запятой:

# %%
list_to_float_1 = ['living_area_part', 'kitchen_area_part']

# %% [markdown]
# Округляем до 2 знаков после запятой:

# %%
for column in list_to_float_1:
    flats[column] = flats[flats[column].notnull()][column].round(2)

# %% [markdown]
# Проверяем, что получилось:

# %%
flats.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.20           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8          NaN  ...
# 1            2.60            11        18.60      1          NaN  ...
# ...

# %% [markdown]
# Столбец last_price приведем к тысячам (к миллионам - нет желания иметь 3 знака после запятой "на всякий случай"), а то слишком много нулей. Ну и, соответственно, тоже самое проделаем для price_of_m2, только там оставим 3 знака после запятой.

# %%
flats['last_price'] = (flats[flats['last_price'].notnull()]['last_price']/1000*1.0).round().astype(int)
flats['price_of_m2'] = (flats[flats['price_of_m2'].notnull()]['price_of_m2']/1000*1.0).round(3)
flats.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20       13000      108.00           2019-03-07      3
# 1             7        3350       40.40           2018-12-04      1
# 2            10        5196       56.00           2015-08-20      2
# 3             0       64900      159.00           2015-07-24      3
# 4             2       10000      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8          NaN  ...
# 1            2.60            11        18.60      1          NaN  ...
# 2            2.60             5        34.30      4          NaN  ...
# 3            2.60            14          nan      9          NaN  ...
# 4            3.00            14        32.00     13          NaN  ...
#
#    ponds_nearest  days_exposition  fromcenter_category  price_of_m2  year  \
# ...

# %% [markdown]
# ## **<font color='IndianRed'> Расчёты и добавление результатов в таблицу </font>**

# %% [markdown]
# **Шаг 3. Посчитайте и добавьте в таблицу:**
# -цену квадратного метра;
# -день недели, месяц и год публикации объявления;
# -этаж квартиры; варианты — первый, последний, другой;
# -соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# Работа сделана частично в "предобработке данных", частично в исследовательском анализе. Так было удобно.

# %% [markdown]
# ## **<font color='LightCoral'> Исследовательский анализ данных </font>**

# %% [markdown]
# **Задание:**
#
# 1. **Изучите следующие параметры:** площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.
# 2. **Изучите время продажи квартиры.** Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
# 3. **Уберите редкие и выбивающиеся значения.** Опишите, какие особенности обнаружили.
# 4. **Какие факторы больше всего влияют на стоимость квартиры?** Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.
# 5. **Выберите 10 населённых пунктов с наибольшим числом объявлений.** Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.
# 6. **Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (locality_name).** Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.
# 7. **Выделите сегмент квартир в центре.** Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# Изучим столбцы: цена, площадь, высота потолков, число комнат.

# %%
flats[['total_area', 'last_price', 'rooms', 'ceiling_height']].describe()
# Out:
#        total_area  last_price     rooms  ceiling_height
# count   23,674.00   23,674.00 23,674.00       23,674.00
# mean        60.36    6,543.40      2.07            2.68
# std         35.67   10,892.22      1.08            0.25
# min         12.00       12.00      0.00            1.00
# 25%         40.00    3,400.00      1.00            2.60
# 50%         52.00    4,650.00      2.00            2.60
# 75%         69.90    6,800.00      3.00            2.70
# max        900.00  763,000.00     19.00           14.00

# %% [markdown]
# **Наблюдения:**
#
# 1. **Минимальная площадь квартиры** - 12 кв.м., максимальная - 900 кв.м. Такие квартиры бывают, я это уже проверила. Насчет 12 кв.м. - как вариант, комната в общежитии, переоборудованная в отдельную квартиру. Либо микроквартира (видела обьявления, где были отдельные квартиры (НЕ комнаты) площадью 9 кв.м.).
# 2. **Цена квартиры.** Минимальная цена -  12 тысяч рублей, максимальная - 763 млн. Насчет последней я проверила,  [квартиры с такими ценами в СПб есть](https://spb.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=flat&region=2&sort=total_price_desc). Что касается квартиры за 12 тыс руб, то обьявление о сдаче квартиры могли по ошибке разместить в раздел "продажа квартиры". Как бы оно там ни было, это значение явно неправдоподобное и это надо исправить.
# 3. **Комнатность** - от 0 (студия) до 19. Квартиры с 19 комнатами в продаже есть, я проверяла (ссылка есть в начале исследования). Или, как вариант, комната в общежитии, где 19 комнат на этаже.
# 4. **Высота потолков** - от 1 до 14 метров. Выше я обосновала, почему именно такая высота и почему я удалила все строки с квартирами, где высота потолков выше 15 метров. Повторяться не буду.

# %% [markdown]
# Узнаем количество строк датафрейма flats для того, чтоб указать выборку при прорисовке статистических графиков:

# %%
print('Выборка квартир в центральной зоне Санкт-Петербурга -', flats.shape[0], 'квартир')
# Out:
# Выборка квартир в центральной зоне Санкт-Петербурга - 23674 квартир

# %% [markdown]
# **Нарисуем гистограммы их распределения (и одну круговую диаграмму для получения распределения по количеству комнат):**
#
# Для начала определим выбросы по каждому из набора данных (что лежит за пределами "усов"):

# %%
rows = 2
columns = 2
fig, axes = plt.subplots(rows, columns, figsize=(50,25))
column_list = ['total_area', 'last_price', 'rooms', 'ceiling_height']
ylims = [600, 13000, 10, 5]
count = 0
for r in range(rows):
    for c in range(columns):
        ax = flats.boxplot(column=column_list[count], ax=axes[r,c], fontsize=40)
        ax.set_ylim([0, ylims[count]])
        count += 1

# %% [markdown]
# **ГРАНИЦЫ:**
#
# **total_area** - 20-130 кв.м.;
#
# **last_price** - 0-12 млн р.;
#
# **rooms** - 0-6 комнат;
#
# **ceiling_height** - 2,4-3,25м.

# %%
plt.style.use('seaborn-pastel')

# %%
plt.style.use('seaborn-pastel') 

# создаем отдельную сводную таблицу для создания круговой диаграммы
rooms_pivot = flats.pivot_table(index='rooms', values='last_price', aggfunc='count')

df_list = [flats['total_area'], flats['last_price'], flats['rooms'], flats['ceiling_height']]
df_titles_list = ['Распределение площадей', 'Распределение цен', 
                  'Распределение по кол-ву комнат (23699 квартир)', 'Распределение по высоте потолков']
xlims_list = [130, 12000, 12, 3.25]
nrow = 2
ncol = 2

def func_pct(pct, data, sum_of_all):
    value = float(pct/100.*sum_of_all)
    if value > 5000:
        return "{:.2f}%\n({:.0f} шт.)".format(pct, value)
    elif value > 1000:
        return "{:.2f}%".format(pct)
    else:
        return ''

fig, axes = plt.subplots(nrows=nrow, ncols=ncol, figsize=(50,25))
count = 0
for r in range(nrow):
    for c in range(ncol):
        if df_titles_list[count] == 'Распределение по кол-ву комнат (23699 квартир)':
            sum_filt_flats = rooms_pivot.sum()
            data_for_pct = rooms_pivot
            ax = rooms_pivot.plot(kind='pie', y="last_price", labels=None,
                                                            autopct = lambda pct: func_pct(pct,data_for_pct,sum_filt_flats),
                                                            radius=1.5, shadow=True, startangle=200, fontsize=40,
                                                            title=df_titles_list[count], legend=True, 
                                                            pctdistance=0.6, labeldistance=0.5, ax=axes[r,c])
            custom_lines = [Line2D([0], [0], color='lightgreen', lw=25),
                            Line2D([0], [0], color='lightsalmon', lw=25),
                            Line2D([0], [0], color='plum', lw=25),
                            Line2D([0], [0], color='yellow', lw=25),
                            Line2D([0], [0], color='paleturquoise', lw=25),
                            Line2D([0], [0], color='skyblue', lw=25)]
            ax.title.set_size(50)
            ax.title.set_position([0.5, 1.15])
            ax.set_ylabel('')
            ax.legend(custom_lines, ['1комн.', '2комн.', '3комн.', '4комн.', '5комн.', '6комн.'], 
                      bbox_to_anchor=(1.1,0.75), prop={'size':40})
            plt.tight_layout(pad=10)
        else:
            ax = df_list[count].plot(kind='hist', bins=400, fontsize=50, title=df_titles_list[count], 
                                     ec='black', ax=axes[r,c])
            if count == 3:
                ax.set_xlim(2.4, xlims_list[count])
                ax.title.set_position([0.5, 1.15])
            else:
                ax.set_xlim(0, xlims_list[count])
            ax.title.set_size(50)
            ax.yaxis.label.set_size(0)
        count += 1

# %% [markdown]
# **Выводы:**
#
#
# **Гистограмма "Распределение площадей":** Общая площадь большинства квартир - от 30 до 80 кв.м., медиана - 50 кв.м. Есть квартиры и по 800м, но это единичные выбросы.
#
# **Гистограмма "Распределение цен":** цены на квартиры - от 3 до 12 млн. Большинство квартир продают за цену от 3 и 6 млн. Здесь тоже есть выбросы, но их мало.
#
# **Круговая диаграмма "Распределение по количеству комнат":** 67% квартир имеют 1 или 2 комнаты, четверть всех квартир  имеют 3 комнаты и небольшое количество (5%) - 4. Есть и квартиры, имеющие больше комнат, но их процент мизерный.
#
# **Гистограмма "Распределение по высоте потолков":** большинство квартир имеют потолки от 2,5-2,75м (самый популярный вариант) до 3,2м. Остальные случаи - эксклюзивы.

# %% [markdown]
# **Задача 2.** Гистрограмма с данными о days_exposition - сколько дней продавалась квартира:

# %%
flats[['days_exposition']].describe()
# Out:
#        days_exposition
# count        23,674.00
# mean            180.81
# std             204.51
# min               1.00
# 25%              45.00
# 50%             124.00
# 75%             199.00
# max           1,580.00

# %%
flats['days_exposition'].median() / 30
# Out:
# 4.133333333333334

# %%
flats['days_exposition'].mean() / 30
# Out:
# 6.026986004336684

# %%
flats['days_exposition'].max() / 365
# Out:
# 4.328767123287672

# %% [markdown]
# Минимальное значение дней экспрозиции квартиры - 1 день. Максимум - 5 лет. В разделе "Изучение данных" я писала про то, что такое бывает и даже приводила ссылку на статью о квартире, которая продавалась 8 лет. Есть гипотеза насчет квартир, которые продаются больше года (а некоторые - по нескольку лет), что это - проблемные квартиры. Там могут быть проблемы с непогашенными долгами по ЖКХ; собственники, которые состоят на учете в алко/нарко/психдиспансере; наследство, которое наследники никак поделить не могут; квартиры, которые продаются с прописанными несовершеннолетними (или с теми прописанными, кто сидит в МЛС); квартиры с постоянно текущей крышей; дом под снос/ренновацию/расселение; квартиры, которые продаются по явно завышенной цене, и так далее. Возможные причины того, почему квартиры стоят на продаже год и больше, можно перечислять долго. Кроме того, сам факт существования проблем с квартирой и/или с ее собственниками имеет место быть в нашей жизни. Поэтому оставим все, как есть. Самое главное - что таких выбросов не так уж много от общего числа. Если бы их было больше - такие данные однозначно пришлось бы удалять.

# %%
print("Количество квартир, которые продавались больше года:", flats[flats['days_exposition'] >= 365].count()[0])
print("Количество квартир, которые продавались больше 2 лет:", flats[flats['days_exposition'] >= 730].count()[0])
print("Количество квартир, которые продавались больше 3 лет:", flats[flats['days_exposition'] >= 1095].count()[0])
print("Количество квартир, которые продавались больше 4 лет:", flats[flats['days_exposition'] >= 1460].count()[0])
# Out:
# Количество квартир, которые продавались больше года: 3059
# Количество квартир, которые продавались больше 2 лет: 751
# Количество квартир, которые продавались больше 3 лет: 170
# Количество квартир, которые продавались больше 4 лет: 11

# %%
flats[['days_exposition']].describe()
# Out:
#        days_exposition
# count        23,674.00
# mean            180.81
# std             204.51
# min               1.00
# 25%              45.00
# 50%             124.00
# 75%             199.00
# max           1,580.00

# %% [markdown]
# **Медианное время продажи квартиры - 124 дня (4 месяца). Среднее - 180 дней (полгода).**

# %%
flats['days_exposition'].hist(bins=70, figsize=(10,5), ec='black')

# %% [markdown]
# Большая часть квартир продавалась в течение первых 50 дней, есть и квартиры, которые продавались до года. Чем дальше, тем реже встречаются такие случаи.

# %%
flats.boxplot(column='days_exposition')

# %% [markdown]
# Ограничу срок продажи годом, чтоб убрать выбросы и изучить данные более детально:

# %%
flats.query('days_exposition<500')['days_exposition'].hist(bins=70, figsize=(10,3), ec='black')

# %% [markdown]
# на этом графике тоже видно, что время продажи квартиры чаще всего от 45 до 60 дней.

# %%
flats.query('40<days_exposition<65')['days_exposition'].hist(bins=90, figsize=(10,3), ec='black')

# %% [markdown]
# Выбросы на 45 и 60 дне закрытия обьявления  о продаже квартиры выглядят странно, но у меня есть гипотеза на этот счет. Возможно, сроки подачи бесплатного обьявления на Циан кратны 15, поэтому они закрываются автоматически, если нет продления, а квартира уже продана.

# %% [markdown]
# **Задача 3**. Зависимость цены от числа комнат, этажа, удалённости от центра и даты размещения объявления

# %% [markdown]
# Совместное распределение для множества величин
# Когда в задаче нужно найти попарные взаимосвязи величин, это можно сделать с
# помощью попарных диаграмм рассеяния. В Pandas такую задачу решают не data.plot() ,
# а специальным методом: pd.plotting.scatter_matrix(data) .

# %% [markdown]
# Для графиков зависимости стоимости квартиры от числа комнат, этажа, удалённости от центра создадим функцию:

# %%
def depend_price(df, column):
    title_dict = {'rooms': 'Зависимость цены от количества комнат', 'level': 'Зависимость цены от этажа',
                  'fromcenter_category': 'Зависимость цены от удаленности от центра города',
                  'day':'Медиана цен по дням недели', 'month': 'Медиана цен по месяцам',
                  'year': 'Медиана цен по годам', 
                  'cityCenters_nearest_kms': 'Зависимость цены от удаленности от центра города'}
    plt.style.use('seaborn-pastel')
    if column == 'level' or column == 'cityCenters_nearest':
        sort_key = 'last_price'
    else:
        sort_key = column
    if column == 'fromcenter_category':
        fontsize = 12
    else:
        fontsize = 15
    df_filtered = df.groupby(column).median()['last_price'].reset_index().sort_values(by=sort_key)
    plot = df_filtered.plot(x=column, y="last_price", kind='bar', ec='black', 
                            title=title_dict[column], legend=None, 
                            fontsize=fontsize, figsize=(9,4))
    ax2 = plt.gca()  # удалим xlabel - у нас и так есть многоговорящее название графика
    x_axis = ax2.xaxis
    x_axis.label.set_visible(False)
    if column != 'cityCenters_nearest_kms':
        plt.xticks(rotation=0)
    return plot

# %%
depend_price(flats, 'rooms')

# %% [markdown]
# Посмотрим на выбивающиеся значения:

# %%
flats.boxplot(column='rooms')

# %% [markdown]
# Смотрим без выбросов:

# %%
depend_price(flats.query('rooms <= 6'), 'rooms')

# %% [markdown]
# Чем больше комнат, тем дороже квартира.
#
# Теперь берёмся за этажи (по категориям: 'первый', 'последний', 'другой').

# %%
depend_price(flats, 'level')

# %% [markdown]
# Самые дешевые квартиры расположены на 1ом этаже, цена в среднем на 20 % ниже, чем квартиры, расположенные на других этажах, кроме последнего. На последнем этаже, конечно, подороже, чем на 1ом, но дешевле чем на других.

# %% [markdown]
# По удалённости от центра по созданным ранее категориям (столбец fromcenter_category):

# %%
depend_price(flats, 'fromcenter_category')

# %% [markdown]
# Теперь изучим зависимость цены от дня недели, месяца и года.

# %% [markdown]
# Построим график зависимости средней цены от дня недели, месяца и года публикации объявления:
#
# Напишем под эти цели свою функцию:

# %%
def dmy_price(df, ylims=None):
    dmy_to_plot = ['day', 'month', 'year']
    titles = ['Медиана цен по дню недели', 'Медиана цен по месяцу', 'Медиана цен по году']

    for i in range(len(dmy_to_plot)):
        df_to_plot = flats.groupby(dmy_to_plot[i]).median()['last_price'].reset_index().sort_values(by=dmy_to_plot[i])
        if ylims is None:
            plot = df_to_plot.plot(x=dmy_to_plot[i], y="last_price", kind='bar', figsize=(10,5), ec='black',
                                   legend=False, title=titles[i], fontsize=15)
        else:
            plot = df_to_plot.plot(x=dmy_to_plot[i], y="last_price", kind='bar', figsize=(10,5), ec='black',
                               legend=False, title=titles[i], fontsize=15, ylim=ylims[i])
        ax2 = plt.gca()
        x_axis = ax2.xaxis
        x_axis.label.set_visible(False)
        if dmy_to_plot[i] != 'day':
            plt.xticks(rotation=0)
    return plot

# %%
dmy_price(flats)

# %% [markdown]
# Из этих данных ничего не понятно. Увеличим размеры каждого графика по вертикали и ограничим каждый график по оси Oy интервалом значений (4000, 4900) для дня недели и месяца и (4000, 8000) для года:

# %%
dmy_price(df=flats, ylims=[(4000, 4900), (4000, 4900), (4000, 8000)])

# %% [markdown]
# Эти данные выглядят более информативно:
#
# 1. От **дня недели** цена практически не зависит. В среднем цены на квартиры, объявление о продажи которых опубликовано в будний день, чуть выше, чем цена на квартиры с объявлениями, опубликованными в выходные дни;
# 2. Зато от **месяца** публикации зависит. Апрель оказался самым "дорогим": цены на квартиры, чьи объявления о продаже были опубликованы в апреле, выше, чем по остальным месяцам. Особенно заметно медиану цен на квартиры по июньским объявлениям - довольно низкие по сравнению с другими месяцами;
# 3. зависимость цены от **года** публикации - 2014г. тут очень выделяется. Рассмотрим его чуть подробнее (по месяцам) и сделаем общий вывод про зависимость цены от года публикации:

# %%
depend_price(flats.query('year == 2014'), 'month')

# %% [markdown]
# Видим, что наши в наших данных есть информация только о ноябре и декабре 2014 года (и позднее).
# Предполагаю, что такие высокие цены были вызваны ажиотажем на рынке недвижимости, вызванным быстрым падением рубля. По этой причине, спрос мог превышать предложение (учитывая то, какими активными участниками рынка стали те же граждане СНГ, у которых валюта пока не ослабла), отсюда и цены такие.
# К декабрю всё пошло на убыль, т.к.:
# 1) валюты граждан других близележащих стран тоже начали слабеть;
# 2) в предновогодний месяц вряд ли вообще рынок недвижимости такой активный.
# В 2019г. цена стала опять расти. Предполагаю, что связано с тем, что после 5 лет застоя рынок недвижимости проснулся - больше и больше граждан могут себе позволить приобрести недвижимость. Рост спроса закономернро приводит к рост цен.

# %% [markdown]
# **Задача 4.**

# %% [markdown]
# Выберем 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья. Данные берем из столбца locality_name.

# %%
top10 = flats['locality_name'].value_counts().index.tolist()[:10]
mean10_metrics = [flats[flats['locality_name'] == city]['price_of_m2'].median().round(2) for city in top10]
mean10_prices = [flats[flats['locality_name'] == city]['last_price'].median() for city in top10]
frame = {'Город': top10, 'Средняя цена за кв.м., тыс. руб.': mean10_metrics, 'Средняя цена за квартиру, тыс. руб.': mean10_prices}
dataframe = pd.DataFrame(frame).sort_values(by='Средняя цена за кв.м., тыс. руб.', ascending=False)
dataframe
# Out:
#                Город  Средняя цена за кв.м., тыс. руб.  \
# 0    Санкт-Петербург                            104.77
# 4             Пушкин                            100.00
# 8    деревня Кудрово                             91.86
# 6  посёлок Парголово                             91.64
# 1     посёлок Мурино                             85.88
# 2     посёлок Шушары                             76.88
# 5            Колпино                             74.72
# 7            Гатчина                             67.86
# 3         Всеволожск                             65.79
# 9             Выборг                             58.16
#
#    Средняя цена за квартиру, тыс. руб.
# 0                             5,500.00
# 4                             5,180.00
# 8                             3,790.00
# 6                             4,100.00
# 1                             3,400.00
# 2                             3,950.00
# 5                             3,600.00
# ...

# %% [markdown]
# Как и ожидалось, самые дорогие квартиры (что за всё жилье, что за 1 кв.м.) в Санкт-Петербурге и парковом городе Пушкине. Чем дальше от города, тем дешевле. В Выборге средняя цена за квадратный метр в 2 раз ниже, чем в Санкт-Петербурге.

# %% [markdown]
# **Задача 5.**

# %% [markdown]
# Изучим предложения квартир. Для каждой квартиры есть информация о расстоянии до центра. Выделим квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создадим столбец с расстоянием до центра в километрах: округлим до целых значений. После этого посчитаем среднюю цену для каждого километра. Построим график: он будет показывать, как цена зависит от удалённости от центра. Определим границу, где график сильно меняется — это и будет центральная зона.

# %%
flats_spb = flats.query('locality_name == "Санкт-Петербург"')
flats_spb.loc[:, 'cityCenters_nearest_kms'] = (flats_spb.loc[:, 'cityCenters_nearest']/1000).round()
flats_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20       13000      108.00           2019-03-07      3
# 2            10        5196       56.00           2015-08-20      2
# 3             0       64900      159.00           2015-07-24      3
# 4             2       10000      100.00           2018-06-19      2
# 7             5        7915       71.60           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70            16        51.00      8          NaN  ...
# 2            2.60             5        34.30      4          NaN  ...
# 3            2.60            14          nan      9          NaN  ...
# 4            3.00            14        32.00     13          NaN  ...
# 7            2.60            24          nan     22          NaN  ...
#
#    days_exposition  fromcenter_category  price_of_m2  year month          day  \
# ...

# %% [markdown]
# Строим график медианной цены в зависимости от удаленности от города:

# %%
depend_price(flats_spb, 'cityCenters_nearest_kms')

# %% [markdown]
# Ожидаемо, что в самом центре (в радиусе до 1 км) медианная цена на квартиру стремится к 20 млн р. Если опираться на резкое падение цены по графику, то центр ограничен радиусом в 8 км, далее медианная цена довольно заметно падает. Однако, цены на 4-7км сравнимы с ценами на квартиры, расположенные в 2 км от центра. Предполагаю, что это влияние на чуть более высокую, чем ожидалось, медианную цену оказывают определенные районы типа Василеостровского, Приморского и Петроградского, которые не считаются центральными, но при этом считаются достаточно элитными.

# %% [markdown]
# Прошу заметить, что на графике присутствуют значения по расстоянию от центра, превышающие 17 км, которые мы определили ранее. Тем не менее, название населенного пункта в этих столбцах - "Санкт-Петербург". Посмотрим на их количество:

# %%
flats_spb.query('cityCenters_nearest_kms > 17').sort_values(by='cityCenters_nearest_kms', ascending=False)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 13031            16        4200       56.80           2018-07-04      2
# 12160             8        2450       43.00           2018-08-14      1
# 16787            20        4850       85.80           2019-04-22      3
# 11652            16        4700       51.00           2016-06-07      2
# 10798            10        4850       62.00           2017-05-16      3
# ...             ...         ...         ...                  ...    ...
# 6653             20        3900       43.00           2016-08-17      2
# 6687             13        4100       50.00           2019-04-02      4
# 6702             11        3880       60.00           2017-07-17      3
# 6827              0        4070       60.00           2017-08-15      3
# 23600             8        8700      132.00           2018-11-13      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Могу предположить, что центр мог считаться не историческим центром Санкт-Петербурга, а какой-либо другой точкой, или же расстояние считалось не по прямой, а по дорогам. А может быть, это Кронштадт, который считается Санкт-Петербургом. Особенно если посмотреть на 27 км от центра, где цены от жилья неожиданно высокие по сравнению с соседними значениями - могут сравниться с ценами в пределах центральной зоны Санкт-Петербурга. В том или ином случае, оставим это как есть, раз информация уже присутствовала в таблице. Тем более, квартир с такими параметрами не так много.

# %% [markdown]
# **Задача 6.**

# %% [markdown]
# Выделим сегмент квартир в центральной зоне (до 8 км включительно) и проанализируем эту территорию - изучим следующие параметры:

# %% [markdown]
# площадь;
# цена;
# число комнат;
# высота потолков.

# %%
flats_in_center = flats_spb.query('cityCenters_nearest <= 8000')

# %% [markdown]
# Узнаем количество строк датафрейма flats_in_center для того, чтоб указать выборку при прорисовке статистических графиков:

# %%
print('Выборка квартир в центральной зоне Санкт-Петербурга -', flats_in_center.shape[0], 'квартир')
# Out:
# Выборка квартир в центральной зоне Санкт-Петербурга - 3726 квартир

# %% [markdown]
# Сначала построим такие же гистограммы распределения для площади, цены, числа комнат и круговую диаграмму для высоты потолков (используем те же лимиты по Ox, которые использовали при построении данных для всего датафрейма):

# %%
# отдельно создадим сводную для круговой диаграммы
flats_in_center_rooms_pivot = flats_in_center.pivot_table(index='rooms', values='last_price', aggfunc='count')

df_list = [flats_in_center['total_area'], flats_in_center['last_price'], 
           flats_in_center['rooms'], flats_in_center['ceiling_height']]
df_titles_list = ['Распределение площадей', 'Распределение цен', 
                  'Распределение по кол-ву комнат (3728 квартир)', 'Распределение по высоте потолков']
xlims_list = [130, 12000, 12, 3.25]

# функция для отображения процентов на pie
def func_pct(pct, data, sum_of_all):
    value = float(pct/100.*sum_of_all)
    if value > 220:
        return "{:.2f}%\n({:.0f} шт.)".format(pct, value)
    elif value > 60:
        return "{:.2f}%".format(pct)
    else:
        return ''

ncol = 2
nrow = 2
fig, axes = plt.subplots(nrows=nrow, ncols=ncol, figsize=(50,25))
line_1 = 'Спасибо тебе!'
count = 0
for r in range(nrow):
    for c in range(ncol):
        if df_titles_list[count] == 'Распределение по кол-ву комнат (3728 квартир)':
            data_for_pct = flats_in_center_rooms_pivot
            sum_filt_flats = flats_in_center_rooms_pivot.sum()
            ax = flats_in_center_rooms_pivot.plot(kind='pie', y="last_price", 
                                                            radius=1.5, shadow=True, startangle=200, fontsize=38,
                                                            autopct = lambda pct: func_pct(pct,data_for_pct,sum_filt_flats),
                                                            title=df_titles_list[count], legend=True, labels=None,
                                                            pctdistance=0.65, labeldistance=0.5, ax=axes[r,c])
            custom_lines = [Line2D([0], [0], color='lightgreen', lw=25),
                            Line2D([0], [0], color='lightsalmon', lw=25),
                            Line2D([0], [0], color='plum', lw=25),
                            Line2D([0], [0], color='yellow', lw=25),
                            Line2D([0], [0], color='paleturquoise', lw=25),
                            Line2D([0], [0], color='skyblue', lw=25)]
            ax.title.set_size(50)
            ax.title.set_position([0.5, 1.15])
            ax.set_ylabel('')
            ax.legend(custom_lines, ['1комн.', '2комн.', '3комн.', '4комн.', '5комн.', '6комн.'], 
                      bbox_to_anchor=(1.1,0.75), prop={'size':40})
            plt.tight_layout(pad=10)
        else:
            ax = df_list[count].plot(kind='hist', bins=400, fontsize=50, title=df_titles_list[count], 
                                     ec='black', ax=axes[r,c])
            if count == 3:
                ax.set_xlim(2.4, xlims_list[count])
                ax.title.set_position([0.5, 2.15])
            else:
                ax.set_xlim(0, xlims_list[count])
            ax.title.set_size(50)
            ax.yaxis.label.set_size(0)
        count += 1

# %% [markdown]
# **1. Гистограмма "Распределение площадей":** Большая часть квартир имеет метраж от 50 до 100 кв.м., пиков много, основные - 60, 70 и 90 кв.м.
# **2. Гистограмма "Распределение цен":** цена на квартиры лежит, в основном, в промежутке от 4,5 до 12 млн р. Большая часть квартир продается за цену в промежутке между 7,5 и 10 млн р.
# **3. Круговая диаграмма "Распределение по количеству комнат":** Больше всего 2- и 3комнатных квартир, чуть меньше - 4хкомнатных. Однокомнатных вообще почти нет (всего 6%) от общего количества.
# **4. Гистограмма "Распределение по высоте потолков":** квартиры, в большинстве своем, имеют потолки 3,25м. Ещё некоторые квартиры имеют высоту потолков от 2,75 до 3,5м. Ниже, выше - редкость.

# %% [markdown]
# Также выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).

# %% [markdown]
# Исследуем зависимость цены на квартиру в центральной зоне Санкт-Петербурга от количества комнат:

# %%
depend_price(flats_in_center, 'rooms')

# %% [markdown]
# Ограничимся 6 комнатами, как при работе со всем датафреймом:

# %%
depend_price(flats_in_center.query('rooms <= 6'), 'rooms')

# %% [markdown]
# Чем больше комнат, тем выше цена. В центре всё просто.

# %% [markdown]
# Зависимость цены от этажа:

# %%
depend_price(flats_in_center, 'level')

# %% [markdown]
# 1ый этаж самый дешевый (аж на 25%), заехать на любой другой этаже будет подороже.

# %% [markdown]
# Зависимость цены от удаленности от центра (в пределах центральной зоны города):

# %%
depend_price(flats_in_center, 'cityCenters_nearest_kms')

# %% [markdown]
# Чем дальше от Дворцовой, тем дешевле.

# %% [markdown]
# Зависимость цены от даты размещения объявления:

# %%
dmy_price(flats_in_center)

# %% [markdown]
# Цена квартиры от дня недели, когда опубликовали объявление о продаже, почти не зависит. Зависимость по месяцу и году опубликованя объявления есть - такая же, как и по всем данным.

# %% [markdown]
# ## **<font color='Coral'> Общий вывод </font>**

# %% [markdown]
# Сделаем выводы и на основе данных о корреляции, и на основе графиков.
#
# Укажем факторы, которые сильнее всего влияют на конечную цену:
#
# **Метраж**	Чем больше площадь квартиры, тем выше цена
# **Цена за квадратный метр** Чем больше цена за квадратный метр, тем выше цена
# **Доля жилой площади/кухни** Чем выше доля жилой площади/площадь кухни, тем выше цена
# **Количество комнат** Чем больше комнат, тем выше цена
# **Этаж** На первом этаже квартира дешевле, чем на остальных; на последнем дороже, чем на первом, но дешевле чем на остальных
# **Удаленность от центра** Чем ближе к центру, тем дороже квартира. В самом центре (< 1 км до центра) квартиры стоят на порядок дороже, чем на более удаленных.
# **День размещения объявления** Квартиры, размещенные к продаже в будние дни, в среднем дороже, чем размещенные в выходные.
# **Месяц размещения объявления** Квартиры, размещенные к продаже в летние месяцы и в октябре, в среднем дешевле, чем размещенные в любые другие месяца. В начале и в конце года цены стабильные и высокие.
# **Год размещения объявления** Квартиры, размещенные к продаже в 2014 году, дороже всех. Период 2015-2018 - период низких цен на квартиры (кризис). 2019г. - рецессия экономики - цены пошли вверх впервые после наступления кризиса.

# %% [markdown]
# ## **<font color='Tomato'> Чек-лист готовности проекта </font>**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
